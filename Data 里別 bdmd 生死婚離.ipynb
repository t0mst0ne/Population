# %%
# %cat opendata-1030*.csv > opendata-all-103.csv
# %ls *.csv
# Out:
# opendata-10305bdmd.csv* opendata-10307bdmd.csv* opendata-10309bdmd.csv*
# opendata-10306bdmd.csv* opendata-10308bdmd.csv* opendata-all-103.csv

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
df = pd.io.parsers.read_csv('opendata-all-103.csv',sep=',').drop('Unnamed: 11',1)

# %%
area = ['花蓮縣花蓮市']
#df.isin(Area)
df[df['區域別'].isin(area)]
# Out:
#        ﻿統計年月     區域別   村里 出生數 出生數-男 出生數-女 死亡數 死亡數-男 死亡數-女 結婚對數 離婚對數
# 3458   10305  花蓮縣花蓮市  主信里   0     0     0   0     0     0    0    0
# 3459   10305  花蓮縣花蓮市  主力里   1     1     0   2     1     1    2    2
# 3460   10305  花蓮縣花蓮市  主勤里   0     0     0   0     0     0    0    0
# 3461   10305  花蓮縣花蓮市  主和里   1     1     0   0     0     0    2    0
# 3462   10305  花蓮縣花蓮市  主商里   0     0     0   1     0     1    0    0
# 3463   10305  花蓮縣花蓮市  主學里   1     0     1   1     1     0    2    0
# 3464   10305  花蓮縣花蓮市  主安里   2     2     0   3     2     1    1    0
# 3465   10305  花蓮縣花蓮市  主工里   0     0     0   1     0     1    0    0
# 3466   10305  花蓮縣花蓮市  主權里   3     2     1   5     4     1    3    0
# 3467   10305  花蓮縣花蓮市  主睦里   0     0     0   0     0     0    0    0
# 3468   10305  花蓮縣花蓮市  主義里   0     0     0   0     0     0    0    0
# 3469   10305  花蓮縣花蓮市  主計里   0     0     0   1     1     0    0    0
# 3470   10305  花蓮縣花蓮市  主農里   1     1     0   2     0     2    3    1
# ...

# %%
area_list = set(df['區域別'])
area_list
df.groupby('區域別').size()
# Out:
# 區域別
# 南投縣中寮鄉    18
# 南投縣仁愛鄉    16
# 南投縣信義鄉    14
# 南投縣南投市    34
# 南投縣名間鄉    23
# 南投縣國姓鄉    13
# 南投縣埔里鎮    33
# 南投縣水里鄉    19
# 南投縣竹山鎮    28
# 南投縣草屯鎮    27
# 南投縣集集鎮    11
# 南投縣魚池鄉    13
# 南投縣鹿谷鄉    13
# 嘉義市東 區    39
# 嘉義市西 區    45
# ...
# 高雄市燕巢區     11
# 高雄市田寮區     10
# 高雄市甲仙區      7
# 高雄市美濃區     19
# 高雄市苓雅區     69
# 高雄市茂林區      3
# 高雄市茄萣區     15
# 高雄市路竹區     20
# 高雄市那瑪夏區     3
# 高雄市阿蓮區     12
# 高雄市鳥松區      7
# 高雄市鳳山一     41
# 高雄市鳳山二     35
# 高雄市鹽埕區     21
# 高雄市鼓山區     38
# Length: 370, dtype: int64
